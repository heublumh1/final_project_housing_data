# %%
import pandas as pd

# %%
predicted_df = pd.read_csv("merged_with_predicted.csv")

# %%
predicted_df.head()
# Out:
#    Unnamed: 0  index          id        date   price_x  sqft_living  sqft_lot  \
# 0           7      7  2008000270  2015-01-15  291850.0         1060      9711
# 1           8      8  2414600126  2015-04-15  229500.0         1780      7470
# 2          12     12   114101516  2014-05-28  310000.0         1430     19901
# 3          16     16  1875500060  2014-07-31  395000.0         1890     14040
# 4          18     18    16000397  2014-12-05  189000.0         1200      9850
#
#    sqft_above  sqft_basement  yr_built  ...  zipcode      lat     long  \
# 0        1060              0      1963  ...    98198  47.4095 -122.315
# 1        1050            730      1960  ...    98146  47.5123 -122.337
# 2        1430              0      1927  ...    98028  47.7558 -122.229
# 3        1890              0      1994  ...    98019  47.7277 -121.962
# 4        1200              0      1921  ...    98002  47.3089 -122.210
#
#    sqft_living15  sqft_lot15  month  year  age   price_y  predicted
# ...

# %%
predicted_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 21 columns):
# Unnamed: 0       4323 non-null int64
# index            4323 non-null int64
# id               4323 non-null int64
# date             4323 non-null object
# price_x          4323 non-null float64
# sqft_living      4323 non-null int64
# sqft_lot         4323 non-null int64
# sqft_above       4323 non-null int64
# sqft_basement    4323 non-null int64
# yr_built         4323 non-null int64
# yr_renovated     4323 non-null int64
# zipcode          4323 non-null int64
# lat              4323 non-null float64
# long             4323 non-null float64
# sqft_living15    4323 non-null int64
# sqft_lot15       4323 non-null int64
# month            4323 non-null int64
# year             4323 non-null int64
# age              4323 non-null int64
# price_y          4323 non-null float64
# predicted        4323 non-null float64
# dtypes: float64(5), int64(15), object(1)
# ...

# %%
predicted_df.rename(columns={'price_y':'price','Predicted':'predicted'}, inplace=True)

# %%
predicted_df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'id', 'date', 'price_x', 'sqft_living',
#        'sqft_lot', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'month',
#        'year', 'age', 'price', 'predicted'],
#       dtype='object')

# %%
predicted_df.drop(columns=['Unnamed: 0', 'price_x'], inplace=True)

# %%
predicted_df.head()
# Out:
#    index          id        date  sqft_living  sqft_lot  sqft_above  \
# 0      7  2008000270  2015-01-15         1060      9711        1060
# 1      8  2414600126  2015-04-15         1780      7470        1050
# 2     12   114101516  2014-05-28         1430     19901        1430
# 3     16  1875500060  2014-07-31         1890     14040        1890
# 4     18    16000397  2014-12-05         1200      9850        1200
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1963             0    98198  47.4095 -122.315
# 1            730      1960             0    98146  47.5123 -122.337
# 2              0      1927             0    98028  47.7558 -122.229
# 3              0      1994             0    98019  47.7277 -121.962
# 4              0      1921             0    98002  47.3089 -122.210
#
#    sqft_living15  sqft_lot15  month  year  age     price  predicted
# 0           1650        9711      1  2015   52  291850.0   274170.6
# ...

# %%
predicted_df['price'] = predicted_df['price'].map('${:,.2f}'.format)

# %%
predicted_df['predicted'] = predicted_df['predicted'].map('${:,.2f}'.format)

# %%
predicted_df.head()
# Out:
#    index          id        date  sqft_living  sqft_lot  sqft_above  \
# 0      7  2008000270  2015-01-15         1060      9711        1060
# 1      8  2414600126  2015-04-15         1780      7470        1050
# 2     12   114101516  2014-05-28         1430     19901        1430
# 3     16  1875500060  2014-07-31         1890     14040        1890
# 4     18    16000397  2014-12-05         1200      9850        1200
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1963             0    98198  47.4095 -122.315
# 1            730      1960             0    98146  47.5123 -122.337
# 2              0      1927             0    98028  47.7558 -122.229
# 3              0      1994             0    98019  47.7277 -121.962
# 4              0      1921             0    98002  47.3089 -122.210
#
#    sqft_living15  sqft_lot15  month  year  age        price    predicted
# 0           1650        9711      1  2015   52  $291,850.00  $274,170.60
# ...

# %%
predicted_df.to_csv("final_predicted_table.csv")
